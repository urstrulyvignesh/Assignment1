# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=jbl+speakers&sid=0pm%2C0o7&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=jbl+speakers%7CSpeakers&requestId=4fd372a5-7d56-4a88-b5d6-c4c3a2c0e0b5&as-searchtext=spe"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
product=BeautifulSoup(response.text)

# %%
product
# Out:
# <!DOCTYPE html>
# ...

# %%
product_rating=product.select("._1lRcqv ._3LWZlK")

# %%
product_rating
# Out:
# [<div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.8<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
# ...

# %%
product_name=product.select(".col-12-12:nth-child(10) .s1Q9rs , .col-12-12:nth-child(9) .s1Q9rs , .col-12-12:nth-child(8) .s1Q9rs , .col-12-12:nth-child(7) .s1Q9rs , ._4HTuuX~ .s1Q9rs , ._2GoDe3+ .col-12-12 .s1Q9rs , ._13oc-S div:nth-child(1) ._4ddWXP .s1Q9rs , ._13oc-S div:nth-child(2) .s1Q9rs , ._13oc-S div:nth-child(3) .s1Q9rs")

# %%
product_name
# Out:
# [<a class="s1Q9rs" href="/boat-aavante-bar-thump-200w-rms-2-1-ch-wired-subwoofer-200-w-bluetooth-soundbar/p/itmc1e6cb37cecf2?pid=ACCGNHJG2Y9HRZUY&amp;lid=LSTACCGNHJG2Y9HRZUYAYVGXX&amp;marketplace=FLIPKART&amp;q=jbl+speakers&amp;store=0pm%2F0o7&amp;srno=s_1_1&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&amp;fm=organic&amp;iid=en_4W3wTM8XzRBhgukZyry8pcCoCdH2Wrv4VemOLBpzgBspgQFGkgwdpTvlcS9HI%2FzJt3ondYtVmDavAIaJMt2%2BJA%3D%3D&amp;ppt=None&amp;ppn=None&amp;ssid=coevk7gmgg0000001680341268552&amp;qH=2ea9581aee816b69" rel="noopener noreferrer" target="_blank" title="boAt Aavante Bar Thump with 200W RMS, 2.1 CH with Wired Subwoofer 200 W Bluetooth Soundbar">boAt Aavante Bar Thump with 200W RMS, 2.1 CH with Wired...</a>,
# ...

# %%
product_price=product.select("._2D5lwg~ ._8VNy32 ._30jeq3")

# %%
product_price
# Out:
# [<div class="_30jeq3">₹8,999</div>,
#  <div class="_30jeq3">₹3,999</div>,
#  <div class="_30jeq3">₹1,899</div>,
#  <div class="_30jeq3">₹1,899</div>,
#  <div class="_30jeq3">₹12,999</div>,
#  <div class="_30jeq3">₹1,899</div>,
#  <div class="_30jeq3">₹10,999</div>,
#  <div class="_30jeq3">₹13,999</div>,
#  <div class="_30jeq3">₹8,999</div>,
#  <div class="_30jeq3">₹3,313</div>,
#  <div class="_30jeq3">₹3,199</div>,
#  <div class="_30jeq3">₹8,999</div>,
#  <div class="_30jeq3">₹5,999</div>,
#  <div class="_30jeq3">₹6,799</div>,
#  <div class="_30jeq3">₹3,222</div>,
#  <div class="_30jeq3">₹5,499</div>,
#  <div class="_30jeq3">₹444</div>,
#  <div class="_30jeq3">₹499</div>,
#  <div class="_30jeq3">₹4,499</div>,
#  <div class="_30jeq3">₹16,999</div>,
#  <div class="_30jeq3">₹3,222</div>,
#  <div class="_30jeq3">₹8,815</div>,
#  <div class="_30jeq3">₹11,999</div>,
#  <div class="_30jeq3">₹42,999</div>,
#  <div class="_30jeq3">₹20,479</div>,
#  <div class="_30jeq3">₹15,879</div>,
# ...

# %%
import pandas as pds

# %%
rating=pds.DataFrame(product_rating)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:540: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
rating
# Out:
#       0   1
# 0   4.2  []
# 1   3.8  []
# 2   4.2  []
# 3   4.2  []
# 4   4.1  []
# 5   4.2  []
# 6   4.4  []
# 7   4.2  []
# 8     4  []
# 9   4.4  []
# 10  4.4  []
# 11  4.3  []
# 12  4.4  []
# 13  4.4  []
# 14  4.4  []
# 15  4.1  []
# 16    4  []
# 17    4  []
# 18  4.4  []
# 19  4.2  []
# 20  4.4  []
# 21  4.4  []
# 22  4.4  []
# 23  4.5  []
# 24  4.5  []
# 25  4.3  []
# 26  4.4  []
# 27  4.4  []
# 28  4.2  []
# 29  4.4  []
# 30  3.8  []
# 31  3.8  []
# 32  4.4  []
# 33  4.4  []
# 34  4.4  []
# 35  4.3  []
# 36  4.5  []
# 37  4.4  []
# 38  4.4  []

# %%
name=pds.DataFrame(product_name)

# %%
name
# Out:
#                                                     0
# 0   boAt Aavante Bar Thump with 200W RMS, 2.1 CH w...
# 1   boAt Aavante Bar Tune with 60W RMS with Sleek ...
# 2   JBL Go Essential with Rich Bass, 5 Hrs Playtim...
# 3   JBL Go Essential with Rich Bass, 5 Hrs Playtim...
# 4   JBL Cinema SB270,Dolby Digital,Wireless Subwoo...
# 5   JBL Go Essential with Rich Bass, 5 Hrs Playtim...
# 6   JBL Flip 6 with 12Hr Playtime, Customize Audio...
# 7     boAt Aavante Bar 3100D 260 W Bluetooth Soundbar
# 8   JBL Cinema SB240 with Dolby Digital Sound with...
# 9                    JBL GO 3 4.2 W Bluetooth Speaker
# 10                    JBL GO3 4.2 W Bluetooth Speaker
# 11    boAt Aavante Bar 1600D 120 W Bluetooth Soundbar
# 12  JBL Flip Essential IPX7 Waterproof 16 W Blueto...
# 13  JBL Flip Essential 2, Deep Bass, 10Hrs Playtim...
# 14                   JBL GO 3 4.2 W Bluetooth Speaker
# 15  boAt Aavante Bar Octave with 2.2 Channel Built...
# ...

# %%
price=pds.DataFrame(product_price)

# %%
price
# Out:
#           0
# 0    ₹8,999
# 1    ₹3,999
# 2    ₹1,899
# 3    ₹1,899
# 4   ₹12,999
# 5    ₹1,899
# 6   ₹10,999
# 7   ₹13,999
# 8    ₹8,999
# 9    ₹3,313
# 10   ₹3,199
# 11   ₹8,999
# 12   ₹5,999
# 13   ₹6,799
# 14   ₹3,222
# 15   ₹5,499
# 16     ₹444
# 17     ₹499
# 18   ₹4,499
# 19  ₹16,999
# 20   ₹3,222
# 21   ₹8,815
# 22  ₹11,999
# 23  ₹42,999
# 24  ₹20,479
# 25  ₹15,879
# 26  ₹54,999
# 27   ₹8,886
# 28  ₹21,999
# 29   ₹4,299
# 30     ₹678
# 31     ₹499
# 32  ₹11,499
# 33   ₹4,299
# 34   ₹8,999
# 35  ₹16,496
# 36  ₹16,999
# 37  ₹10,999
# 38   ₹4,499

# %%
speakers=pds.DataFrame({'name':product_name,'rating':product_rating,'price':product_price})

# %%
speakers
# Out:
#                                                  name     rating      price
# 0   [boAt Aavante Bar Thump with 200W RMS, 2.1 CH ...  [4.2, []]   [₹8,999]
# 1   [boAt Aavante Bar Tune with 60W RMS with Sleek...  [3.8, []]   [₹3,999]
# 2   [JBL Go Essential with Rich Bass, 5 Hrs Playti...  [4.2, []]   [₹1,899]
# 3   [JBL Go Essential with Rich Bass, 5 Hrs Playti...  [4.2, []]   [₹1,899]
# 4   [JBL Cinema SB270,Dolby Digital,Wireless Subwo...  [4.1, []]  [₹12,999]
# 5   [JBL Go Essential with Rich Bass, 5 Hrs Playti...  [4.2, []]   [₹1,899]
# 6   [JBL Flip 6 with 12Hr Playtime, Customize Audi...  [4.4, []]  [₹10,999]
# 7   [boAt Aavante Bar 3100D 260 W Bluetooth Soundbar]  [4.2, []]  [₹13,999]
# 8   [JBL Cinema SB240 with Dolby Digital Sound wit...    [4, []]   [₹8,999]
# 9                  [JBL GO 3 4.2 W Bluetooth Speaker]  [4.4, []]   [₹3,313]
# 10                  [JBL GO3 4.2 W Bluetooth Speaker]  [4.4, []]   [₹3,199]
# ...

# %%
d=speakers.to_csv("C:/Users/Admin/Desktop/products.csv")

# %%
d

# %%
file=pds.read_csv("C:/Users/Admin/Desktop/products.csv")

# %%
file
# Out:
#     Unnamed: 0                                               name  \
# 0            0  <a class="s1Q9rs" href="/boat-aavante-bar-thum...
# 1            1  <a class="s1Q9rs" href="/boat-aavante-bar-tune...
# 2            2  <a class="s1Q9rs" href="/jbl-go-essential-rich...
# 3            3  <a class="s1Q9rs" href="/jbl-go-essential-rich...
# 4            4  <a class="s1Q9rs" href="/jbl-cinema-sb270-dolb...
# 5            5  <a class="s1Q9rs" href="/jbl-go-essential-rich...
# 6            6  <a class="s1Q9rs" href="/jbl-flip-6-12hr-playt...
# 7            7  <a class="s1Q9rs" href="/boat-aavante-bar-3100...
# 8            8  <a class="s1Q9rs" href="/jbl-cinema-sb240-dolb...
# 9            9  <a class="s1Q9rs" href="/jbl-go-3-4-2-w-blueto...
# 10          10  <a class="s1Q9rs" href="/jbl-go3-4-2-w-bluetoo...
# 11          11  <a class="s1Q9rs" href="/boat-aavante-bar-1600...
# 12          12  <a class="s1Q9rs" href="/jbl-flip-essential-ip...
# ...

# %%
edit=file['name']

# %%
edit
# Out:
# 0     <a class="s1Q9rs" href="/boat-aavante-bar-thum...
# 1     <a class="s1Q9rs" href="/boat-aavante-bar-tune...
# 2     <a class="s1Q9rs" href="/jbl-go-essential-rich...
# 3     <a class="s1Q9rs" href="/jbl-go-essential-rich...
# 4     <a class="s1Q9rs" href="/jbl-cinema-sb270-dolb...
# 5     <a class="s1Q9rs" href="/jbl-go-essential-rich...
# 6     <a class="s1Q9rs" href="/jbl-flip-6-12hr-playt...
# 7     <a class="s1Q9rs" href="/boat-aavante-bar-3100...
# 8     <a class="s1Q9rs" href="/jbl-cinema-sb240-dolb...
# 9     <a class="s1Q9rs" href="/jbl-go-3-4-2-w-blueto...
# 10    <a class="s1Q9rs" href="/jbl-go3-4-2-w-bluetoo...
# 11    <a class="s1Q9rs" href="/boat-aavante-bar-1600...
# 12    <a class="s1Q9rs" href="/jbl-flip-essential-ip...
# 13    <a class="s1Q9rs" href="/jbl-flip-essential-2-...
# 14    <a class="s1Q9rs" href="/jbl-go-3-4-2-w-blueto...
# 15    <a class="s1Q9rs" href="/boat-aavante-bar-octa...
# 16    <a class="s1Q9rs" href="/zsiv-10w-dj-mini-spea...
# ...

# %%
edit=edit.str.strip('<a class="s1Q9rs" href="/').astype(str)

# %%
edit
# Out:
# 0     boat-aavante-bar-thump-200w-rms-2-1-ch-wired-s...
# 1     boat-aavante-bar-tune-60w-rms-sleek-design-rem...
# 2     jbl-go-essential-rich-bass-5-hrs-playtime-ipx7...
# 3     jbl-go-essential-rich-bass-5-hrs-playtime-ipx7...
# 4     jbl-cinema-sb270-dolby-digital-wireless-subwoo...
# 5     jbl-go-essential-rich-bass-5-hrs-playtime-ipx7...
# 6     jbl-flip-6-12hr-playtime-customize-audio-app-i...
# 7     boat-aavante-bar-3100d-260-w-bluetooth-soundba...
# 8     jbl-cinema-sb240-dolby-digital-sound-remote-hd...
# 9     jbl-go-3-4-2-w-bluetooth-speaker/p/itm63ed62ad...
# 10    jbl-go3-4-2-w-bluetooth-speaker/p/itm51be5c1e6...
# 11    boat-aavante-bar-1600d-120-w-bluetooth-soundba...
# 12    jbl-flip-essential-ipx7-waterproof-16-w-blueto...
# 13    jbl-flip-essential-2-deep-bass-10hrs-playtime-...
# 14    jbl-go-3-4-2-w-bluetooth-speaker/p/itmadd6de5c...
# 15    boat-aavante-bar-octave-2-2-channel-built-subw...
# 16    zsiv-10w-dj-mini-speaker-3d-bass-new-arrival-w...
# ...

# %%
edit=file['rating']

# %%
edit
# Out:
# 0     <div class="_3LWZlK">4.2<img class="_1wB99o" s...
# 1     <div class="_3LWZlK">3.8<img class="_1wB99o" s...
# 2     <div class="_3LWZlK">4.2<img class="_1wB99o" s...
# 3     <div class="_3LWZlK">4.2<img class="_1wB99o" s...
# 4     <div class="_3LWZlK">4.1<img class="_1wB99o" s...
# 5     <div class="_3LWZlK">4.2<img class="_1wB99o" s...
# 6     <div class="_3LWZlK">4.4<img class="_1wB99o" s...
# 7     <div class="_3LWZlK">4.2<img class="_1wB99o" s...
# 8     <div class="_3LWZlK">4<img class="_1wB99o" src...
# 9     <div class="_3LWZlK">4.4<img class="_1wB99o" s...
# 10    <div class="_3LWZlK">4.4<img class="_1wB99o" s...
# 11    <div class="_3LWZlK">4.3<img class="_1wB99o" s...
# 12    <div class="_3LWZlK">4.4<img class="_1wB99o" s...
# 13    <div class="_3LWZlK">4.4<img class="_1wB99o" s...
# 14    <div class="_3LWZlK">4.4<img class="_1wB99o" s...
# 15    <div class="_3LWZlK">4.1<img class="_1wB99o" s...
# 16    <div class="_3LWZlK">4<img class="_1wB99o" src...
# ...

# %%
edit=edit.int.strip('<div class="_3LWZlK">4.2<img class="_1wB99o" s...').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6596/2861650599.py in <module>
# ----> 1 edit=edit.int.strip('<div class="_3LWZlK">4.2<img class="_1wB99o" s...').astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'int'
